# %% [markdown]
# # Load packages

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from matplotlib.pyplot import figure
from PIL import Image
import requests
from io import BytesIO
import os
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
import re
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# # Load data

# %% [markdown]
# ## Content based

# %%
# COSINE MATRIX
cs_matrix_file = './Data/cs_matrix_content.pkl'
with open(cs_matrix_file, 'rb') as f:
  cs_matrix_content = pickle.load(f)

# PRODUCT DATA
p_data_file = './Data/p_data.pkl'
with open(p_data_file, 'rb') as f:
  p_data = pickle.load(f)

# %% [markdown]
# ## Collaborative

# %%
# PRODUCT DATA LIST
pkl_product_file = './Data/products_processed.pkl'
with open(pkl_product_file, 'rb') as f:
  all_product_data_list = pickle.load(f)

# PRODUCT REVIEW LIST
pkl_review_file = './Data/reviews_processed.pkl'
with open(pkl_review_file, 'rb') as f:
  all_review_data_list = pickle.load(f)

# COSINE MATRIX
cs_matrix_file = './Data/cs_matrix_collaborative.pkl'
with open(cs_matrix_file, 'rb') as f:
  cs_matrix_collaborative = pickle.load(f)

# USER ITEM RATING
user_item_rating_file = './Data/user_item_rating.pkl'
with open(user_item_rating_file, 'rb') as f:
  user_item_rating = pickle.load(f)

# DEMOGS
review_data_nodup_melt_file = './Data/review_data_nodup_melt.pkl'
with open(review_data_nodup_melt_file, 'rb') as f:
  review_data_nodup_melt = pickle.load(f)

# %%
review_data_nodup_melt.head()
# Out:
#     user_id variable  value  user_mapping  variable_mapping
# 0  17725300      age   29.0           454             14897
# 1  12064814      age   40.0          7490             14897
# 2  18524231      age   23.0         11172             14897
# 3   6382654      age   30.0           177             14897
# 4  12090782      age   31.0           420             14897

# %%
user_item_rating.head()
# Out:
#    user_id       variable  value  user_mapping  variable_mapping
# 0  1000190   Product_ASR8     10          1280              2694
# 1  1000190   Product_COC2     10          1280              1074
# 2  1000190   Product_CR17      8          1280              6743
# 3  1000190   Product_DL89      8          1280              1931
# 4  1000190  Product_DLC25      8          1280              3709

# %%
p_data.head()
# Out:
#                                created     designer_name  \
# FLN35 2019-06-20 19:47:21.891000+00:00        Flynn Skye
# RMB77 2019-07-24 19:20:14.655000+00:00        Ramy Brook
# KPL81 2019-06-20 19:47:13.135000+00:00       The Kooples
# STS90 2019-06-20 16:27:34.753000+00:00      STYLESTALKER
# PR125 2019-07-16 21:15:40.619000+00:00  Proenza Schouler
#
#                               displayName  formalityScore  \
# FLN35                   Maiden Mini Dress             3.0
# RMB77                     Silver Lori Top             5.0
# KPL81                  Leopard Robe Dress             3.0
# STS90         Olive Velvet Leila Jumpsuit             5.0
# PR125  Crocodile Print Matte Jersey Dress             3.0
#
#                                           productDetails  \
# FLN35  Brown leopard printed crepe (100% Rayon). Hour...
# RMB77  Silver silk (95% Silk, 5% Spandex). Top. Sleev...
# KPL81  Brown leopard printed silk (100% Silk). Hourgl...
# ...

# %%
print('Data successfully loaded')
